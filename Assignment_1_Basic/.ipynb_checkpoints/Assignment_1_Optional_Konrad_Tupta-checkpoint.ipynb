# %%
# Importing Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import textwrap

#Graphs visual settings
import matplotlib
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# # Assigment 1 Optional Dataset - Survey2021 stackoverflow.com
# ## Part 0
# ### Data Loading & Preparation
#  In this part, firstly I have loaded the code from 2 files 'survey_results_public.csv' & 'survey_results_schema.csv'. Then I declared the functions that will be used to prepare the charts.
#
#  Data: [Stack Overflow Insights](https://insights.stackoverflow.com/survey)

# %%
# Importing Dataset 
public_df = pd.read_csv('survey_results_public.csv')
public_df.head()

# .head() function as default is loading 5 records. 
# If we want to load more or less items, we must enter the appropriate number in parentheses.
# Out:
#    ResponseId                                         MainBranch  \
# 0           1                     I am a developer by profession
# 1           2             I am a student who is learning to code
# 2           3  I am not primarily a developer, but I write co...
# 3           4                     I am a developer by profession
# 4           5                     I am a developer by profession
#
#                                           Employment  \
# 0  Independent contractor, freelancer, or self-em...
# 1                                 Student, full-time
# 2                                 Student, full-time
# 3                                 Employed full-time
# 4  Independent contractor, freelancer, or self-em...
#
#                                              Country US_State UK_Country  \
# 0                                           Slovakia      NaN        NaN
# 1                                        Netherlands      NaN        NaN
# ...

# %%
# Importing Dataset
schema_df = pd.read_csv('survey_results_schema.csv')
schema_df.head()

# .head() function as default is loading 5 records. 
# If we want to load more or less items, we must enter the appropriate number in parentheses
# Out:
#      qid       qname                                           question  \
# 0  QID16          S0  <div><span style="font-size:19px;"><strong>Hel...
# 1  QID12    MetaInfo                                  Browser Meta Info
# 2   QID1          S1  <span style="font-size:22px; font-family: aria...
# 3   QID2  MainBranch  Which of the following options best describes ...
# 4  QID24  Employment  Which of the following best describes your cur...
#
#    force_resp  type selector
# 0       False    DB       TB
# 1       False  Meta  Browser
# 2       False    DB       TB
# 3        True    MC     SAVR
# 4       False    MC     MAVR

# %%
# features
public_df.columns

# columns attribute to return the column labels of the given Dataframe.
# Out:
# Index(['ResponseId', 'MainBranch', 'Employment', 'Country', 'US_State',
#        'UK_Country', 'EdLevel', 'Age1stCode', 'LearnCode', 'YearsCode',
#        'YearsCodePro', 'DevType', 'OrgSize', 'Currency', 'CompTotal',
#        'CompFreq', 'LanguageHaveWorkedWith', 'LanguageWantToWorkWith',
#        'DatabaseHaveWorkedWith', 'DatabaseWantToWorkWith',
#        'PlatformHaveWorkedWith', 'PlatformWantToWorkWith',
#        'WebframeHaveWorkedWith', 'WebframeWantToWorkWith',
#        'MiscTechHaveWorkedWith', 'MiscTechWantToWorkWith',
#        'ToolsTechHaveWorkedWith', 'ToolsTechWantToWorkWith',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith', 'OpSys',
#        'NEWStuck', 'NEWSOSites', 'SOVisitFreq', 'SOAccount', 'SOPartFreq',
#        'SOComm', 'NEWOtherComms', 'Age', 'Gender', 'Trans', 'Sexuality',
#        'Ethnicity', 'Accessibility', 'MentalHealth', 'SurveyLength',
#        'SurveyEase', 'ConvertedCompYearly'],
#       dtype='object')

# %%
# features
schema_df.columns

# columns attribute to return the column labels of the given Dataframe.
# Out:
# Index(['qid', 'qname', 'question', 'force_resp', 'type', 'selector'], dtype='object')

# %%
# features
public_df.info()

# Print a concise summary of a DataFrame.
# This method prints information about a DataFrame including the index dtype and columns, 
# non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
# features
schema_df.info()

# Print a concise summary of a DataFrame.
# This method prints information about a DataFrame including the index dtype and columns, 
# non-null values and memory usage.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   qid         48 non-null     object
#  1   qname       48 non-null     object
#  2   question    48 non-null     object
#  3   force_resp  48 non-null     bool
#  4   type        48 non-null     object
#  5   selector    48 non-null     object
# dtypes: bool(1), object(5)
# memory usage: 2.0+ KB

# %%
# Pie chart to show gender statistics. In my opinion, it is ideal for presenting a percentage share.
    
# This function takes the name of the column as a parameter and x which is the number 
# of items we want to display in our plot for example:
# if x = 10 then the chart will only include the first 10 items.

#Plot Function:
def pie(parameter, x):
    # Preparing datadrame 
    dataframe = public_df[parameter].value_counts().head(x)
    
    # Printing dataframe
    print(dataframe)
    
    # Preparing plot
    plt.figure(figsize = (7, 7))
    # I made my own color list, because I wanted this chart to match with the others.
    color_set = ['#e5eef6', '#d4e1ee', '#bdd3e3', '#9dc2d5', '#78aac8', '#5a94ba', '#3f7baa', '#29649a', '#386290']
    # plt.pie() is uded to plot a pie chart
    plt.pie(dataframe, labels = dataframe.index, autopct = '%1.1f%%', startangle = 180, colors = color_set);

# %%
# I have defined below a function, that will be used to create and print charts. 

# This function takes the name of the column as a parameter and x which is the number 
# of items we want to display in our plot for example:
# if x = 10 then the chart will only include the first 10 items.
    
#Plot Function:
def plot(parameter, x):
  # Preparing datadrame 
  dataframe = pd.DataFrame(public_df[parameter].str.get_dummies(';').sum())
  dataframe.reset_index(inplace = True)
  dataframe.columns = [parameter, 'Quantity']
  dataframe = dataframe.sort_values('Quantity', ascending = False).head(x)

  # Printing dataframe
  print(dataframe)

  # Preparing plot
  plt.figure(figsize=(18, 12))
  sns.barplot(x = parameter, y = 'Quantity', data = dataframe, palette = "Blues")
  plt.xticks(rotation = 60, horizontalalignment = 'right')

# %% [markdown]
# ## Part 1
# ### Gender
#
# Below we have the pie chart showing the percentage of each sex. As can be clearly seen in the chart, as many as 92.3% of the portal's users are men. This statistic is a bit of a surprise to me. I expected most of them to be men, but I thought that the percentage of women would be slightly higher.

# %%
# Here I'm using function 'pie(parameter, x)' which was declared in part 1.
pie('Gender', 4)
# As we can see below we have 4 options.
# Below I have listed the exact number of people declaring a given gender and plotted a proper graph.
# Out:
# Man                                                  74817
# Woman                                                 4120
# Prefer not to say                                     1442
# Non-binary, genderqueer, or gender non-conforming      690
# Name: Gender, dtype: int64

# %% [markdown]
# ## Part 2
# ### Origin Countries of Users
#
# As we can see from the data presented below, the vast majority of stacoverflow.com users come from the United States of America (15288). India is in second place with the number 10511. The podium is closed by Germany with the number 5625. The 8th place in Poland may be surprising with the number of users 1805.
#
# It is also worth noting that the first two places are occupied by the countries where English is spoken.

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('Country', 10)
# Because .function takes 10 as parameter we will only get first 10 positions with the biggest number of users.
# x label - Country
# y label - Quantity
# Below I have listed the exact number of people from a given country and plotted proper graph.
# Out:
#                                                Country  Quantity
# 173                           United States of America     15288
# 69                                               India     10511
# 58                                             Germany      5625
# 171  United Kingdom of Great Britain and Northern I...      4475
# 29                                              Canada      3012
# 55                                              France      2708
# 22                                              Brazil      2254
# 128                                             Poland      1805
# 112                                        Netherlands      1772
# 76                                               Italy      1666

# %% [markdown]
# ## Part 3
# ### Age of the users
#
# Most users of stackoverflow.com are in the age range from 25 to 34 years old. In my opinion, the whole age distribution is no surprise and is in line with my expectations.

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('Age', 8)
# As we can see below we have 8 age ranges.
# x label - Age
# y label - Quantity
# Below I have listed the exact number of people declaring a given age and plotted proper graph.
# Out:
#                   Age  Quantity
# 1     25-34 years old     32568
# 0     18-24 years old     20993
# 2     35-44 years old     15183
# 3     45-54 years old      5472
# 7  Under 18 years old      5376
# 4     55-64 years old      1819
# 6   Prefer not to say       575
# 5   65 years or older       421

# %% [markdown]
# # Part 4
# ### Level of Education
# Below I presented the education level of stack overflow users. As you can easily notice on our chart, the list of people with the Bachelor’s degree is significantly higher than the others (over 35k). The number of people with a bachelor's degree is almost twice as high as the group with a master's degree.

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('EdLevel', 8)
# x label - Education Level
# y label - Quantity
# As we can see below we have 8 different types of educations levels.
# Below I have listed the exact number of people declaring a given education level and plotted proper graph.
# Out:
#                                              EdLevel  Quantity
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)     35357
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)     17512
# 7  Some college/university study without earning ...     10589
# 6  Secondary school (e.g. American high school, G...      9534
# 3         Other doctoral degree (Ph.D., Ed.D., etc.)      2567
# 4                          Primary/elementary school      2479
# 0                Associate degree (A.A., A.S., etc.)      2231
# 8                                     Something else      1601

# %% [markdown]
# # Part 5
# ###  Language Have Worked With
#
# Below is a chart showing the most popular languages among stackoverflow users. The javascrpt language comes first.
# The html & css web techonlogies are in second place. The second place probably comes from the fact that if we want to use javascript we are kind of forced to use html & css at the same time. Therefore, second place is no surprise. The podium is closed with python.

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('LanguageHaveWorkedWith', 50)
# x label - Programming Languages
# y label - Quantity
# Below I have listed the exact number of people using a given programming language and plotted proper graph.
# Out:
#    LanguageHaveWorkedWith  Quantity
# 19             JavaScript     53587
# 16               HTML/CSS     46259
# 29                 Python     39792
# 33                    SQL     38835
# 18                   Java     29162
# 24                Node.js     27975
# 36             TypeScript     24909
# 4                      C#     22984
# 2              Bash/Shell     22385
# 5                     C++     20057
# 26                    PHP     18130
# 3                       C     17329
# 28             PowerShell      8871
# 14                     Go      7879
# 21                 Kotlin      6866
# 32                   Rust      5799
# 31                   Ruby      5569
# 9                    Dart      4965
# 1                Assembly      4632
# 35                  Swift      4204
# 30                      R      4185
# 37                    VBA      3847
# 23                 Matlab      3846
# 15                 Groovy      2479
# 25            Objective-C      2310
# ...

# %% [markdown]
# # Part 6
# ### Age 1st code
#
# Below we have the pie chart showing the percentage of age in which users started programming. More than half of users started their adventure with programming between the ages of 11 and 17.

# %%
# Here I'm using function 'pie(parameter, x)' which was declared in part 1.
pie('Age1stCode', 8)
# As we can see below we have 8 age ranges.
# Below I have listed the exact number of people divided according to the age 
# at which they started programming and plotted proper graph.
# Out:
# 11 - 17 years           44170
# 18 - 24 years           20065
# 5 - 10 years            11720
# 25 - 34 years            4199
# 35 - 44 years            1312
# Younger than 5 years      905
# 45 - 54 years             544
# 55 - 64 years             245
# Name: Age1stCode, dtype: int64

# %% [markdown]
# # Part 7
# ### Most Popular IDEs
#
# The chart below shows the most popular IDE (Integrated Development Environment) among stackoverflow.com users. It is easy to notice that Visual Studio Code dominates the rest. Most likely, this is due to the fact that in this IDE we are able to write using almost any available technology. Other IDEs are often limited to a certain group of languages, e.g. in Intellij we can only write in Java and its frameworks. Therefore the rest of the IDEs have a smaller target audience.

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('NEWCollabToolsHaveWorkedWith', 20)
# x label - NEWCollabToolsHaveWorkedWith
# y label - Quantity
# Below I have listed the exact number of people using a given IDE and plotted proper graph.
# Out:
#    NEWCollabToolsHaveWorkedWith  Quantity
# 18           Visual Studio Code     58026
# 17                Visual Studio     26970
# 8                     Notepad++     24262
# 5                      IntelliJ     23467
# 16                          Vim     19752
# 0                Android Studio     18141
# 14                 Sublime Text     16714
# 10                      PyCharm     15755
# 2                       Eclipse     12955
# 1                          Atom     10564
# 4               IPython/Jupyter     10310
# 20                        Xcode      9040
# 19                     Webstorm      6564
# 9                      PHPStorm      6096
# 7                      NetBeans      5839
# 3                         Emacs      4327
# 6                        Neovim      4071
# 12                        Rider      3255
# 11                      RStudio      3200
# 13                     RubyMine      1219

# %% [markdown]
# # Part 8
# ### Most Popular Operating Systems
#
# The chart below shows the most popular operating systems among stackoverflow.com users. Almost half of the users declare that they use Windows (45.3%). Almost the same number use Linux-like systems and MacOs(25.3% & 25.2%).

# %%
# Here I'm using function 'pie(parameter, x)'' which was declared in part 1.
pie('OpSys', 6)
# As we can see below we have 6 options.
# Below I have listed the exact number of people using a given operating system and plotted proper graph.
# Out:
# Windows                              37758
# Linux-based                          21088
# MacOS                                20984
# Windows Subsystem for Linux (WSL)     2743
# Other (please specify):                575
# BSD                                    146
# Name: OpSys, dtype: int64

# %% [markdown]
# # Part 9
# ### Most popular ways to learn programming
#
# The chart below shows the the most popular ways to learn programming among stackoverflow.com users. As you can see in the chart below, the most popular way to learn programming are online materials (49392). The next slightly less popular methods are: School (44462) and Books (42752).

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('LearnCode', 20)
# x label - NEWCollabToolsHaveWorkedWith
# y label - Quantity
# Below I have listed the exact number of people using a given IDE and plotted proper graph.
# Out:
#                                          LearnCode  Quantity
# 7  Other online resources (ex: videos, blogs, etc)     49392
# 8                                           School     44462
# 0                           Books / Physical media     42752
# 4                  Online Courses or Certification     33511
# 5                                     Online Forum     26229
# 3                          Friend or family member     15162
# 2                                        Colleague     14225
# 1                                  Coding Bootcamp      8496
# 6                          Other (please specify):      6924

# %% [markdown]
# # Part 10
# ### Ethnicity
#
# The chart below shows that a significant proportion of the portal's users are of origin White or of European descent (over 42k). the second largest group is people of ethnicity: South Asian (over 8k). This data makes a lot of sense if we compare it with the data from part 2, where many of the users were from countries in Europe or North America(here first is White or of European descent) and second were people from India (here second is South Asian).

# %%
# Here I'm using function 'plot(parameter, x)' which was declared in part 1.
plot('Ethnicity', 13)
# x label - Ethnicity
# y label - Quantity
# Below I have listed the exact number of people declaring a given ethnicity and plotted proper graph.
# Out:
#                                             Ethnicity  Quantity
# 12                       White or of European descent     46434
# 10                                        South Asian      9214
# 3                              Hispanic or Latino/a/x      5570
# 6                                      Middle Eastern      4222
# 11                                    Southeast Asian      4083
# 2                                          East Asian      3735
# 9                                   Prefer not to say      3062
# 8                              Or, in your own words:      2916
# 1                         Black or of African descent      2686
# 4                                        I don't know      2684
# 7                                         Multiracial      1317
# 0                                            Biracial       939
# 5   Indigenous (such as Native American, Pacific I...       575

# %% [markdown]
# ## TO SUM UP:
#
#
# The above statistics give us a general overview of not only who the users of stackoverflow.com are, but also who the programmers themselves are.
# I think most of this data is not surprising:
# ###### -PART 1 Gender: The vast majority of users are men (92.3%);
# ###### -PART 2 Origin Countries of Users: The US ranks first with the number of users 15288;
# ###### -PART 3 Age of the users: Most users are in the age range from 25 to 34 years old;
# ###### -PART 4 Level of Education: Most users have a bachelor's degree (over 35k), followed by people with a master's degree (over 17k);
# ###### -PART 5 Language Have Worked With: The most popular nowadays is js, followed by html & css which are strongly related to js;
# ###### -PART 6 Age 1st Code: More than half of users started their adventure with programming between the ages of 11 and 17;
# ###### -PART 7 Most popular IDEs: By far the most popular IDE is Visual Studio Code;
# ###### -PART 8 Most popular Operating System: The most popular operating system is Windows;
# ###### -PART 9 Most popular ways to learn programming: The most popular way to learn programming are online materials (almost 50k of users);
# ###### -PART 10 Ethnicity: The vast majority of users are of origin White or of European descent (46434);
